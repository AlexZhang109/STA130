# %% [markdown]
# 1. Explain succinctly in your own words (but working with a ChatBot if needed)...
#
# the difference between Simple Linear Regression and Multiple Linear Regression; and the benefit the latter provides over the former：
#
# Simple linear regression uses one independent variable to predict the outcome of the dependent variable, while multi-linear regression uses muliple independent variable to predict the outcome of the dependent variable. Therefore, the latter has a better prediction accuracy in more complex model due to multiple factors used.
#
# the difference between using a continuous variable and an indicator variable in Simple Linear Regression; and these two linear forms:
#
# Continous variable are usually used to represent a range of numbers in an interval, such as age and height, and it shows the rate of change for that varibale. while indicator variable are binary numbers(0/1) to represent categorical variables like gender(male/female), it can let us find the categorical distinction.
#
# the change that happens in the behavior of the model (i.e., the expected nature of the data it models) when a single indicator variable is introduced alongside a continuous variable to create a Multiple Linear Regression; and these two linear forms (i.e., the Simple Linear Regression versus the Multiple Linear Regression)
#
# the model of multi-linear regression can capture differences in the continuous effect across two categories. While the simple linear regression can only captures level differences between two groups.
#
# Chatbot history: https://chatgpt.com/share/67365fcb-bdc4-8004-bf60-bd7b187af53e

# %% [markdown]
# 4. Explain the apparent contradiction between the factual statements regarding the fit below that "the model only explains 17.6% of the variability in the data" while at the same time "many of the coefficients are larger than 10 while having strong or very strong evidence against the null hypothesis of 'no effect'"

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv"
# fail https://github.com/KeithGalli/pandas/blob/master/pokemon_data.csv
pokeaman = pd.read_csv(url) 
pokeaman

import statsmodels.formula.api as smf

model1_spec = smf.ols(formula='HP ~ Q("Sp. Def") + C(Generation)', data=pokeaman)
model2_spec = smf.ols(formula='HP ~ Q("Sp. Def") + C(Generation) + Q("Sp. Def"):C(Generation)', data=pokeaman)
model2_spec = smf.ols(formula='HP ~ Q("Sp. Def") * C(Generation)', data=pokeaman)

model2_fit = model2_spec.fit()
model2_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.176
# Model:                            OLS   Adj. R-squared:                  0.164
# Method:                 Least Squares   F-statistic:                     15.27
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):           3.50e-27
# Time:                        20:41:03   Log-Likelihood:                -3649.4
# No. Observations:                 800   AIC:                             7323.
# Df Residuals:                     788   BIC:                             7379.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# R-squared measures the proportion of the variation in the outcome variable explained by the model as a whole. In this case, an R-squared of 17.6% implies that the model explains only a small portion of the variability in the outcome. This does not necessarily mean the model is poor in all respects; it simply indicates that other unexplained factors account for most of the outcome's variation.
# On the other hand,  p-values shows the strength of evidence against the null hypothesis that the coefficients are zero (no effect). A low p-value for a coefficient suggests strong evidence that this independent variable has a significant relationship with the outcome variable, assuming other predictors are not changing.
# For categorical predictors like "Generation," Using "Generation 1" as a baseline and make other generations as binary indicators allows each generation level to have its own effect on the outcome, without implying a continuous orrelationship. While there's only a 17.6% of the model variation, but in this range, we can rejcet the null hypothesis.

# %% [markdown]
# 7. Discuss with a ChatBot the rationale and principles by which model5_linear_form is extended and developed from model3_fit and model4_fit; model6_linear_form is extended and developed from model5_linear_form; and model7_linear_form is extended and developed from model6_linear_form; then, explain this breifly and consisely in your own words

# %% [markdown]
# Model5: Includes core predictors (Attack, Defense, Speed, Legendary) and categorical variables (Generation, Type 1, Type 2), aiming to find the most obvious characteristics influencing HP.
# Model6: Simplifies the model by focusing only on significant predictors from Model5, removing less significant variables like Defense. It also uses specific indicator functions for Type 1 (Normal, Water) and Generation (2, 5) to isolate potentially impactful categories.
# Model7: Introduces interaction effects between core continuous predictors, hypothesizing that these interactions might better capture complex relationships influencing HP. By including interactions (e.g., Attack * Speed * Sp. Def * Sp. Atk), the model can find some compounded effect of these stats on HP.
#
# chatbot history: https://chatgpt.com/share/673663fd-6e7c-8004-ba9d-b86e7269b30f

# %% [markdown]
# 9. Work with a ChatBot to understand the meaning of the illustration below; and, explain this in your own words

# %% [markdown]
# Model 7, Generation 1:
# Model 7 is fitted only on Generation 1 data, the r^2 shows how well this model fits Generation 1 data. R^2 evaluates the model's predictions for generations other than Generation 1. This tests whether the relationships found in Generation 1 can generalize to other generations.
# Model 7, Generations 1 to 5:
# Here, Model 7 is trained on all generations except Generation 6. The "in-sample" R2 shows how well it fits Generations 1 to 5. R2 is calculated by testing the model on Generation 6, evaluating if the relationships found in Generations 1 to 5 can predict Generation 6 Pokémon's HP.
# Model 6, Generation 1:
# Model 6 is fitted only on Generation 1 data. R2 values are calculated the same way as for Model 7, comparing the fit on Generation 1 and generalization to other generations.
# Model 6, Generations 1 to 5:
# Model 6 is trained on all generations except Generation 6. Its ability to generalize to Generation 6 is assessed by comparing the in-sample fit on Generations 1 to 5 with the out-of-sample fit on Generation 6
#
# chatbot history: https://chatgpt.com/share/673663fd-6e7c-8004-ba9d-b86e7269b30f
